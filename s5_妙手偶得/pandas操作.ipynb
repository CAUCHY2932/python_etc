# %% [markdown]
# ## 列操作

# %%
import pandas as pd

# %%
file_name = r'C:\Users\LvYangyang\Desktop\工作\20190627\一地一策\水晶剑历史宴会数据汇总2017-2019-清洗后-1.xlsx'
sheet_name = '水晶剑历史宴会汇总'
df = pd.read_excel(file_name, nrows=100,sheet_name=sheet_name)
print(df)
# Out:
#                宴会编码  办事处   区域城市  举办地属性  主任岗位编码   主任岗位名称  主任员工编码  主任姓名  \
# 0   SJJ201811120011  苏南办  无锡主城区    NaN     NaN  苏南办事处主任     NaN   NaN
# 1   SJJ201811170026  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 2   SJJ201811110029  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 3   SJJ201811170044  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 4   SJJ201811170125  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 5   SJJ201811170223  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 6   SJJ201811170228  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 7   SJJ201811170055  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 8   SJJ201811180055  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 9   SJJ201811180062  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 10  SJJ201811180085  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 11  SJJ201811170007  苏南办  苏州主城区    NaN     NaN  苏南办事处主任     NaN   NaN
# ...

# %%
df.columns
# Out:
# Index(['宴会编码', '办事处', '区域城市', '举办地属性', '主任岗位编码', '主任岗位名称', '主任员工编码', '主任姓名',
#        '城市经理岗位编码', '城市经理岗位名称', '经理员工编码', '经理姓名', '申报业务员编码', '申报业务员姓名',
#        '跟单人员编码', '跟单人员姓名', '经销商编码', '经销商名称', '终端编码', '终端名称', '终端地址', '终端省',
#        '终端市', '终端区', '宴会日期', '年', '月', '宴会时间段', '宴会类型', '宴会地址', '宴会省', '宴会市',
#        '宴会区', '用酒品类', '申报购酒数量', '申报桌数', '消费者姓名', '消费者联系电话', '宴会备注', '审核桌数',
#        '审核用酒数', '审核用酒品项', '产品名称', '度数', '版本', '最终审核结果', '市场类型', '跟单方式', '数据来源',
#        '复审审核结果', '是否为试点烟酒', '试点烟酒判定结果', '备注'],
#       dtype='object')

# %%
df2 = df[["宴会编码", "办事处", "区域城市", "宴会日期"]]

# %%
df2
# Out:
#                宴会编码  办事处   区域城市       宴会日期
# 0   SJJ201811120011  苏南办  无锡主城区 2018-11-13
# 1   SJJ201811170026  苏南办    太仓市 2018-11-17
# 2   SJJ201811110029  苏南办    太仓市 2018-11-11
# 3   SJJ201811170044  苏南办    太仓市 2018-11-17
# 4   SJJ201811170125  苏南办    太仓市 2018-11-18
# 5   SJJ201811170223  苏南办    太仓市 2018-11-18
# 6   SJJ201811170228  苏南办    太仓市 2018-11-18
# 7   SJJ201811170055  苏南办    吴江区 2018-11-17
# 8   SJJ201811180055  苏南办    吴江区 2018-11-18
# 9   SJJ201811180062  苏南办    吴江区 2018-11-18
# 10  SJJ201811180085  苏南办    吴江区 2018-11-18
# 11  SJJ201811170007  苏南办  苏州主城区 2018-11-17
# 12  SJJ201811160152  苏南办  苏州主城区 2018-11-17
# 13  SJJ201811170178  苏南办  苏州主城区 2018-11-18
# 14  SJJ201811160060  苏南办  苏州主城区 2018-11-17
# 15  SJJ201811170229  苏南办  苏州主城区 2018-11-18
# 16  SJJ201811170231  苏南办  苏州主城区 2018-11-18
# 17  SJJ201811170233  苏南办  苏州主城区 2018-11-18
# 18  SJJ201811100006  苏南办  苏州主城区 2018-11-10
# 19  SJJ201811160188  苏南办  苏州主城区 2018-11-17
# 20  SJJ201811160194  苏南办  苏州主城区 2018-11-18
# ...

# %%
df2["办事处"] = None
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                宴会编码  办事处   区域城市  举办地属性  主任岗位编码   主任岗位名称  主任员工编码  主任姓名  \
# 0   SJJ201811120011  苏南办  无锡主城区    NaN     NaN  苏南办事处主任     NaN   NaN
# 1   SJJ201811170026  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 2   SJJ201811110029  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 3   SJJ201811170044  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 4   SJJ201811170125  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 5   SJJ201811170223  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 6   SJJ201811170228  苏南办    太仓市    NaN     NaN  苏南办事处主任     NaN   NaN
# 7   SJJ201811170055  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 8   SJJ201811180055  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 9   SJJ201811180062  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 10  SJJ201811180085  苏南办    吴江区    NaN     NaN  苏南办事处主任     NaN   NaN
# 11  SJJ201811170007  苏南办  苏州主城区    NaN     NaN  苏南办事处主任     NaN   NaN
# ...
