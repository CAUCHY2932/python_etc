# %%
import pandas as pd
import os

# %%
file_path = r'C:\Users\LvYangyang\Desktop\untitled\upload\upload_oa.xlsx'
data = pd.read_excel(file_path, nrows=10)

# %%
data
# Out:
#            序号    大区        办事处  办事处岗位编码  办事处主任员工编码 办事处主任姓名  城市经理岗位编码  \
# 0  MC00160000  销售四区  川北办事处（一部）      412        647     陈达春       543
# 1  MC00160001  销售四区  重庆办事处（一部）    10053        537     韦道孔     10066
# 2  MC00160002  销售四区  重庆办事处（一部）    10053        537     韦道孔     10066
# 3  MC00160003  销售五区  苏北办事处（一部）      405       1395     陆红军      7363
# 4  MC00160004  销售三区  江西办事处（一部）      406       1032     杨留配       507
# 5  MC00160005  销售三区  江西办事处（一部）      406       1032     杨留配       507
# 6  MC00160006  销售三区  江西办事处（一部）      406       1032     杨留配       507
# 7  MC00160007  销售三区  江西办事处（一部）      406       1032     杨留配       507
# 8  MC00160008  销售四区  重庆办事处（一部）    10053        537     韦道孔     10066
# 9  MC00160009  销售四区  湖北办事处（一部）     6883       3336     王一博      8209
#
#    城市经理岗位名称  城市经理员工编号         城市经理姓名 ...   核销金额  支付比例  支付方式   支付金额  核销批次  \
# 0    绵阳城市经理       620  宋蜀红(00000620) ...  11000     1    折扣  11000   NaN
# ...
